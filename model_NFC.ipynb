# %%
#import library

import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
#create data from random ineteger

data = pd.DataFrame({
    'user_id' : np.random.randint(1, 100, 1000),
    'item_id' : np.random.randint(1, 50, 1000),
    'rating' : np.random.randint(1, 6, 1000)
})

data.head(5)
# Out:
#    user_id  item_id  rating
# 0       92        3       4
# 1        9       38       3
# 2       71       22       4
# 3       79       48       4
# 4       50       45       5

# %%
#membagi dataset menjadi 80% training dan 20% test

train, test = train_test_split(data, test_size=0.2)

# %%
#menghitung jumlah user dan item yang unique

number_users = data['user_id'].nunique()
number_items = data['item_id'].nunique()

number_users, number_items
# Out:
# (99, 49)

# %%
#create model NCF

user_input = tf.keras.layers.Input(shape=(1,))
item_input = tf.keras.layers.Input(shape=(1,))

user_embedding = tf.keras.layers.Embedding(number_users + 1, 50)(user_input)
item_embedding = tf.keras.layers.Embedding(number_items + 1, 50)(item_input)

user_flat = tf.keras.layers.Flatten()(user_embedding)
item_flat = tf.keras.layers.Flatten()(item_embedding)

concat = tf.keras.layers.Concatenate()([user_flat, item_flat])
dropout_1 = tf.keras.layers.Dropout(0.2)(concat)
dense_1 = tf.keras.layers.Dense(128, activation='relu')(dropout_1)
dropout_2 = tf.keras.layers.Dropout(0.2)(dense_1)
dense_2 = tf.keras.layers.Dense(64, activation='relu')(dropout_2)
output = tf.keras.layers.Dense(1)(dense_2)

model = tf.keras.models.Model(inputs=[user_input, item_input], outputs=output)

model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 1)]                  0         []
#
#  input_10 (InputLayer)       [(None, 1)]                  0         []
#
#  embedding_8 (Embedding)     (None, 1, 50)                5000      ['input_9[0][0]']
#
#  embedding_9 (Embedding)     (None, 1, 50)                2500      ['input_10[0][0]']
#
#  flatten_8 (Flatten)         (None, 50)                   0         ['embedding_8[0][0]']
#
#  flatten_9 (Flatten)         (None, 50)                   0         ['embedding_9[0][0]']
#
#  concatenate_4 (Concatenate  (None, 100)                  0         ['flatten_8[0][0]',
#  )                                                                   'flatten_9[0][0]']
#
#  dropout_8 (Dropout)         (None, 100)                  0         ['concatenate_4[0][0]']
#
#  dense_12 (Dense)            (None, 128)                  12928     ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 128)                  0         ['dense_12[0][0]']
#
#  dense_13 (Dense)            (None, 64)                   8256      ['dropout_9[0][0]']
#
#  dense_14 (Dense)            (None, 1)                    65        ['dense_13[0][0]']
#
# ==================================================================================================
# Total params: 28749 (112.30 KB)
# Trainable params: 28749 (112.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
#model compiler with optimizer and loss mse

model.compile(optimizer='rmsprop', loss='mean_squared_error')

# %%
#training data with model

model.fit([train['user_id'], train['item_id']], train['rating'], epochs=100, batch_size=32, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/100
# 20/20 - 2s - loss: 7.6579 - val_loss: 3.8934 - 2s/epoch - 88ms/step
# Epoch 2/100
# 20/20 - 0s - loss: 2.4555 - val_loss: 2.1169 - 92ms/epoch - 5ms/step
# Epoch 3/100
# 20/20 - 0s - loss: 1.9510 - val_loss: 2.1980 - 95ms/epoch - 5ms/step
# Epoch 4/100
# 20/20 - 0s - loss: 1.9006 - val_loss: 2.3350 - 115ms/epoch - 6ms/step
# Epoch 5/100
# 20/20 - 0s - loss: 1.8358 - val_loss: 2.3438 - 98ms/epoch - 5ms/step
# Epoch 6/100
# 20/20 - 0s - loss: 1.7658 - val_loss: 2.4560 - 116ms/epoch - 6ms/step
# Epoch 7/100
# 20/20 - 0s - loss: 1.7582 - val_loss: 2.4803 - 106ms/epoch - 5ms/step
# Epoch 8/100
# 20/20 - 0s - loss: 1.8039 - val_loss: 2.5100 - 89ms/epoch - 4ms/step
# Epoch 9/100
# 20/20 - 0s - loss: 1.7471 - val_loss: 2.5376 - 106ms/epoch - 5ms/step
# Epoch 10/100
# 20/20 - 0s - loss: 1.7431 - val_loss: 2.5254 - 128ms/epoch - 6ms/step
# Epoch 11/100
# 20/20 - 0s - loss: 1.7194 - val_loss: 2.5666 - 98ms/epoch - 5ms/step
# Epoch 12/100
# 20/20 - 0s - loss: 1.7239 - val_loss: 2.5900 - 118ms/epoch - 6ms/step
# Epoch 13/100
# 20/20 - 0s - loss: 1.6650 - val_loss: 2.6099 - 105ms/epoch - 5ms/step
# Epoch 14/100
# 20/20 - 0s - loss: 1.6923 - val_loss: 2.6290 - 94ms/epoch - 5ms/step
# Epoch 15/100
# 20/20 - 0s - loss: 1.6643 - val_loss: 2.5968 - 110ms/epoch - 6ms/step
# Epoch 16/100
# 20/20 - 0s - loss: 1.6670 - val_loss: 2.6139 - 97ms/epoch - 5ms/step
# Epoch 17/100
# 20/20 - 0s - loss: 1.6645 - val_loss: 2.6105 - 128ms/epoch - 6ms/step
# Epoch 18/100
# 20/20 - 0s - loss: 1.6675 - val_loss: 2.6034 - 172ms/epoch - 9ms/step
# Epoch 19/100
# 20/20 - 0s - loss: 1.6444 - val_loss: 2.5896 - 158ms/epoch - 8ms/step
# Epoch 20/100
# 20/20 - 0s - loss: 1.6203 - val_loss: 2.6505 - 112ms/epoch - 6ms/step
# Epoch 21/100
# 20/20 - 0s - loss: 1.5898 - val_loss: 2.5985 - 113ms/epoch - 6ms/step
# Epoch 22/100
# 20/20 - 0s - loss: 1.5949 - val_loss: 2.5710 - 99ms/epoch - 5ms/step
# Epoch 23/100
# 20/20 - 0s - loss: 1.5690 - val_loss: 2.5937 - 98ms/epoch - 5ms/step
# Epoch 24/100
# 20/20 - 0s - loss: 1.5548 - val_loss: 2.5913 - 94ms/epoch - 5ms/step
# Epoch 25/100
# 20/20 - 0s - loss: 1.5331 - val_loss: 2.6327 - 83ms/epoch - 4ms/step
# Epoch 26/100
# 20/20 - 0s - loss: 1.5141 - val_loss: 2.6332 - 94ms/epoch - 5ms/step
# Epoch 27/100
# 20/20 - 0s - loss: 1.5061 - val_loss: 2.6026 - 99ms/epoch - 5ms/step
# Epoch 28/100
# 20/20 - 0s - loss: 1.4541 - val_loss: 2.5964 - 83ms/epoch - 4ms/step
# Epoch 29/100
# 20/20 - 0s - loss: 1.4235 - val_loss: 2.6623 - 87ms/epoch - 4ms/step
# Epoch 30/100
# 20/20 - 0s - loss: 1.3651 - val_loss: 2.6485 - 90ms/epoch - 4ms/step
# Epoch 31/100
# 20/20 - 0s - loss: 1.3638 - val_loss: 2.5927 - 88ms/epoch - 4ms/step
# Epoch 32/100
# 20/20 - 0s - loss: 1.3064 - val_loss: 2.5460 - 98ms/epoch - 5ms/step
# Epoch 33/100
# 20/20 - 0s - loss: 1.2784 - val_loss: 2.6039 - 83ms/epoch - 4ms/step
# Epoch 34/100
# 20/20 - 0s - loss: 1.2034 - val_loss: 2.6114 - 90ms/epoch - 5ms/step
# Epoch 35/100
# 20/20 - 0s - loss: 1.1780 - val_loss: 2.6601 - 71ms/epoch - 4ms/step
# Epoch 36/100
# 20/20 - 0s - loss: 1.1304 - val_loss: 2.6390 - 92ms/epoch - 5ms/step
# Epoch 37/100
# 20/20 - 0s - loss: 1.0722 - val_loss: 2.6217 - 102ms/epoch - 5ms/step
# Epoch 38/100
# 20/20 - 0s - loss: 1.0837 - val_loss: 2.6001 - 116ms/epoch - 6ms/step
# Epoch 39/100
# 20/20 - 0s - loss: 1.0650 - val_loss: 2.6163 - 110ms/epoch - 6ms/step
# Epoch 40/100
# 20/20 - 0s - loss: 0.9543 - val_loss: 2.6524 - 93ms/epoch - 5ms/step
# Epoch 41/100
# 20/20 - 0s - loss: 0.9613 - val_loss: 2.6835 - 122ms/epoch - 6ms/step
# Epoch 42/100
# 20/20 - 0s - loss: 0.9494 - val_loss: 2.7675 - 113ms/epoch - 6ms/step
# Epoch 43/100
# 20/20 - 0s - loss: 0.8941 - val_loss: 2.6994 - 107ms/epoch - 5ms/step
# Epoch 44/100
# 20/20 - 0s - loss: 0.8978 - val_loss: 2.7201 - 98ms/epoch - 5ms/step
# Epoch 45/100
# 20/20 - 0s - loss: 0.8777 - val_loss: 2.7547 - 107ms/epoch - 5ms/step
# Epoch 46/100
# 20/20 - 0s - loss: 0.8051 - val_loss: 2.7475 - 159ms/epoch - 8ms/step
# Epoch 47/100
# 20/20 - 0s - loss: 0.7977 - val_loss: 2.7754 - 254ms/epoch - 13ms/step
# Epoch 48/100
# 20/20 - 0s - loss: 0.8081 - val_loss: 2.7494 - 205ms/epoch - 10ms/step
# Epoch 49/100
# 20/20 - 0s - loss: 0.7642 - val_loss: 2.7894 - 173ms/epoch - 9ms/step
# Epoch 50/100
# 20/20 - 0s - loss: 0.7522 - val_loss: 2.8879 - 260ms/epoch - 13ms/step
# Epoch 51/100
# 20/20 - 0s - loss: 0.7180 - val_loss: 2.7605 - 263ms/epoch - 13ms/step
# Epoch 52/100
# 20/20 - 0s - loss: 0.6779 - val_loss: 2.8548 - 304ms/epoch - 15ms/step
# Epoch 53/100
# 20/20 - 0s - loss: 0.7328 - val_loss: 2.8028 - 320ms/epoch - 16ms/step
# Epoch 54/100
# 20/20 - 0s - loss: 0.6473 - val_loss: 2.8249 - 249ms/epoch - 12ms/step
# Epoch 55/100
# 20/20 - 0s - loss: 0.6939 - val_loss: 2.8717 - 250ms/epoch - 12ms/step
# Epoch 56/100
# 20/20 - 0s - loss: 0.6656 - val_loss: 2.9734 - 286ms/epoch - 14ms/step
# Epoch 57/100
# 20/20 - 0s - loss: 0.6542 - val_loss: 2.8663 - 273ms/epoch - 14ms/step
# Epoch 58/100
# 20/20 - 0s - loss: 0.5900 - val_loss: 2.8563 - 225ms/epoch - 11ms/step
# Epoch 59/100
# 20/20 - 0s - loss: 0.6042 - val_loss: 2.9921 - 268ms/epoch - 13ms/step
# Epoch 60/100
# 20/20 - 0s - loss: 0.6433 - val_loss: 2.9236 - 291ms/epoch - 15ms/step
# Epoch 61/100
# 20/20 - 0s - loss: 0.6433 - val_loss: 2.9807 - 273ms/epoch - 14ms/step
# Epoch 62/100
# 20/20 - 0s - loss: 0.5953 - val_loss: 2.9643 - 300ms/epoch - 15ms/step
# Epoch 63/100
# 20/20 - 0s - loss: 0.6295 - val_loss: 3.0349 - 332ms/epoch - 17ms/step
# Epoch 64/100
# 20/20 - 0s - loss: 0.5926 - val_loss: 3.0218 - 420ms/epoch - 21ms/step
# Epoch 65/100
# 20/20 - 0s - loss: 0.5367 - val_loss: 2.9942 - 207ms/epoch - 10ms/step
# Epoch 66/100
# 20/20 - 0s - loss: 0.5622 - val_loss: 3.0342 - 196ms/epoch - 10ms/step
# Epoch 67/100
# 20/20 - 0s - loss: 0.5980 - val_loss: 3.0447 - 158ms/epoch - 8ms/step
# Epoch 68/100
# 20/20 - 0s - loss: 0.5793 - val_loss: 2.9851 - 141ms/epoch - 7ms/step
# Epoch 69/100
# 20/20 - 0s - loss: 0.5735 - val_loss: 2.9694 - 243ms/epoch - 12ms/step
# Epoch 70/100
# 20/20 - 0s - loss: 0.5755 - val_loss: 2.9728 - 165ms/epoch - 8ms/step
# Epoch 71/100
# 20/20 - 0s - loss: 0.5421 - val_loss: 3.0253 - 240ms/epoch - 12ms/step
# Epoch 72/100
# 20/20 - 0s - loss: 0.5305 - val_loss: 3.0018 - 118ms/epoch - 6ms/step
# Epoch 73/100
# 20/20 - 0s - loss: 0.5618 - val_loss: 3.0442 - 139ms/epoch - 7ms/step
# Epoch 74/100
# 20/20 - 0s - loss: 0.5827 - val_loss: 2.9713 - 162ms/epoch - 8ms/step
# Epoch 75/100
# 20/20 - 0s - loss: 0.5282 - val_loss: 2.9867 - 170ms/epoch - 8ms/step
# Epoch 76/100
# 20/20 - 0s - loss: 0.5563 - val_loss: 3.0758 - 232ms/epoch - 12ms/step
# Epoch 77/100
# 20/20 - 0s - loss: 0.5891 - val_loss: 3.0183 - 282ms/epoch - 14ms/step
# Epoch 78/100
# 20/20 - 0s - loss: 0.5652 - val_loss: 3.0808 - 180ms/epoch - 9ms/step
# Epoch 79/100
# 20/20 - 0s - loss: 0.5755 - val_loss: 3.0538 - 155ms/epoch - 8ms/step
# Epoch 80/100
# 20/20 - 0s - loss: 0.5176 - val_loss: 3.0456 - 192ms/epoch - 10ms/step
# Epoch 81/100
# 20/20 - 0s - loss: 0.5562 - val_loss: 3.0242 - 183ms/epoch - 9ms/step
# Epoch 82/100
# 20/20 - 0s - loss: 0.5511 - val_loss: 3.0619 - 217ms/epoch - 11ms/step
# Epoch 83/100
# 20/20 - 0s - loss: 0.4982 - val_loss: 3.1109 - 384ms/epoch - 19ms/step
# Epoch 84/100
# 20/20 - 0s - loss: 0.4925 - val_loss: 3.0602 - 193ms/epoch - 10ms/step
# Epoch 85/100
# 20/20 - 0s - loss: 0.5046 - val_loss: 3.0088 - 154ms/epoch - 8ms/step
# Epoch 86/100
# 20/20 - 0s - loss: 0.5004 - val_loss: 3.1155 - 235ms/epoch - 12ms/step
# Epoch 87/100
# 20/20 - 0s - loss: 0.4943 - val_loss: 3.0606 - 247ms/epoch - 12ms/step
# Epoch 88/100
# 20/20 - 0s - loss: 0.5187 - val_loss: 3.0454 - 245ms/epoch - 12ms/step
# Epoch 89/100
# 20/20 - 0s - loss: 0.4807 - val_loss: 3.0608 - 242ms/epoch - 12ms/step
# Epoch 90/100
# 20/20 - 0s - loss: 0.5025 - val_loss: 3.0215 - 228ms/epoch - 11ms/step
# Epoch 91/100
# 20/20 - 0s - loss: 0.4614 - val_loss: 3.0731 - 210ms/epoch - 11ms/step
# Epoch 92/100
# 20/20 - 0s - loss: 0.5271 - val_loss: 3.1013 - 136ms/epoch - 7ms/step
# Epoch 93/100
# 20/20 - 0s - loss: 0.4412 - val_loss: 3.0888 - 91ms/epoch - 5ms/step
# Epoch 94/100
# 20/20 - 0s - loss: 0.4837 - val_loss: 3.0459 - 79ms/epoch - 4ms/step
# Epoch 95/100
# 20/20 - 0s - loss: 0.5302 - val_loss: 3.0542 - 77ms/epoch - 4ms/step
# Epoch 96/100
# 20/20 - 0s - loss: 0.4552 - val_loss: 2.9530 - 78ms/epoch - 4ms/step
# Epoch 97/100
# 20/20 - 0s - loss: 0.5000 - val_loss: 3.0206 - 77ms/epoch - 4ms/step
# Epoch 98/100
# 20/20 - 0s - loss: 0.4645 - val_loss: 3.0687 - 79ms/epoch - 4ms/step
# Epoch 99/100
# 20/20 - 0s - loss: 0.4958 - val_loss: 3.2061 - 86ms/epoch - 4ms/step
# Epoch 100/100
# 20/20 - 0s - loss: 0.4495 - val_loss: 3.0626 - 83ms/epoch - 4ms/step

# %%
#evaluate model with test data

result = model.evaluate([test['user_id'], test['item_id']], test['rating'])
result
# Out:
# 7/7 [==============================] - 0s 4ms/step - loss: 2.6700
# 2.6699814796447754
